# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
font = {'size':17}
matplotlib.rc('font', **font)
rcParams['figure.figsize'] = 8, 8

# %%
raw_data = loadtxt("../data/201320/notas_fisicaII_201320.dat")

# %%
p1 = raw_data[:,0]
p2 = raw_data[:,1]
p3 = raw_data[:,2]
exos = raw_data[:,4]
final = raw_data[:,5]
definitiva = p1*0.2 + p2*0.2 + p3*0.2 + final*0.3 + exos*0.1
x = linspace(0,100,100)

# %%
scatter(definitiva, p1,s=100, alpha=0.5)
plot(x,x, linewidth=4)
xlim([40.0,100.0])
ylim([20.0,120.0])

xlabel("Nota definitiva")
ylabel("Nota primer parcial")

# %%
scatter(definitiva, p2,s=100, alpha=0.5)
plot(x,x, linewidth=4)
xlim([40.0,100.0])
ylim([20.0,100.0])
xlabel("Nota definitiva")
ylabel("Nota segundo parcial")

# %%
scatter(definitiva, p3,s=100, alpha=0.5)
plot(x,x, linewidth=4)
xlim([40.0,100.0])
ylim([20.0,110.0])
xlabel("Nota definitiva")
ylabel("Nota tercer parcial")

# %%
scatter(definitiva, final,s=100, alpha=0.5)
plot(x,x, linewidth=4)
xlim([40.0,100.0])
ylim([20.0,100.0])
xlabel("Nota definitiva")
ylabel("Nota examen final")

# %%
scatter(definitiva, exos,s=100, alpha=0.5)
plot(x,x, linewidth=4)
xlim([40.0,100.0])
ylim([20.0,110.0])
xlabel("Nota definitiva")
ylabel("Nota complementaria")

# %%
scatter(definitiva, 0.5*(p1+p2),s=100, alpha=0.5)
plot(x,x, linewidth=4)
xlim([40.0,100.0])
ylim([20.0,110.0])
xlabel("Nota definitiva")
ylabel("Promedio primeros dos parciales")

# %%
print size(definitiva)
print size(where(definitiva<60))
# Out:
# 61
# 16

# %%
raw_data = loadtxt("../data/201410/notas_fisicaII_201410.dat")

# %%
p1_2014 = raw_data[:,0]
fig = figure(figsize=(9.5,6.5))
ax = axes()
n, bins, patches = hist(p1_2014, 20, normed=0, color = 'silver')
ax.set_xlim([0,100])
xlabel("Nota Primer Parcial")
ylabel("# estudiantes")
print median(p1_2014)
# Out:
# 55.0

# %%
p2_2014 = raw_data[:,1]
fig = figure(figsize=(9.5,6.5))
ax = axes()
n, bins, patches = hist(p2_2014, 20, normed=0, color = 'red', alpha=0.8)
n, bins, patches = hist(p1_2014, 20, normed=0, color = 'black', alpha=0.7)
ax.set_xlim([0,100])
xlabel("Nota Segundo Parcial")
ylabel("# estudiantes")
print median(p1_2014)
# Out:
# 55.0

# %%
scatter(p1_2014, p2_2014)

# %%
n, bins, patches = hist(0.5*(p2_2014 + p1_2014), 20, normed=0, color = 'red', alpha=0.8)
n, bins, patches = hist(0.5*(p2 + p1 ), 20, normed=0, color = 'black', alpha=0.8)

# %%
ave = 0.5*(p2_2014 + p1_2014)
print size(where(ave>50.0))
print median(ave)
print average(ave)
# Out:
# 54
# 56.1
# 54.3192307692
